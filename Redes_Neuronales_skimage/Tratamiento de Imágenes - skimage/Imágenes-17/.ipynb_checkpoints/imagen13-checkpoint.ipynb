# %%
from skimage import io
from skimage import draw
img = io.imread('puppy.jpg')
print(img.shape)
#Define Bezier curve coordinates
x, y = draw.bezier_curve(0,0, 50, 100, 100, 50, 1000)
#Draw Bezier curve
img[x, y] = 1
#Show image
io.imshow(img)
# Out:
# (177, 284, 3)
